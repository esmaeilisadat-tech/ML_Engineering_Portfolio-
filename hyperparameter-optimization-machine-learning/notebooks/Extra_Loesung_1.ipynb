# %% [markdown]
# ## Dataset Validation
# Run this cell to verify that your datasets are present and correctly formatted.

# %%
# --- DATASET VALIDATION ---
import os
import pandas as pd

def validate_dataset(filepath, expected_columns=None, avoid_columns=None):
    if not os.path.exists(filepath):
        print(f'❌ ERROR: Dataset not found at {filepath}')
        return False
    try:
        df = pd.read_csv(filepath, nrows=5)
        print(f'✅ SUCCESS: Dataset found at {filepath} (Columns: {df.shape[1]})')
        if expected_columns:
            missing = [c for c in expected_columns if c not in df.columns]
            if missing:
                print(f'⚠️ WARNING: Missing expected columns: {missing}')
                return False
        if avoid_columns:
            forbidden = [c for c in avoid_columns if c in df.columns]
            if forbidden:
                print(f'❌ ERROR: Found forbidden columns {forbidden}. Wrong dataset!')
                return False
        return True
    except Exception as e:
        print(f'❌ ERROR: Could not read dataset: {e}')
        return False

print('Validating Santander Dataset...')
validate_dataset('../data/train.csv', expected_columns=['target', 'var_0'], avoid_columns=['Survived', 'PassengerId'])

# %%
# %pip install -r requirements.txt

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Setup

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(ROOT / 'src'))

from hyperparameter_tuning_solution import (
    DATA_DIR, TABLE_DIR, FIG_DIR, save_table, save_bar,
    sonar_experiments, auto_insurance_experiments, nested_cv_experiment,
    hyperopt_mobile_experiment
)

import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4 ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
#       5 sys.path.append(str(ROOT / 'src'))
#       6
# ----> 7 from hyperparameter_tuning_solution import (
#       8     DATA_DIR, TABLE_DIR, FIG_DIR, save_table, save_bar,
#       9     sonar_experiments, auto_insurance_experiments, nested_cv_experiment,
#      10     hyperopt_mobile_experiment
#
# ModuleNotFoundError: No module named 'hyperparameter_tuning_solution'

# %% [markdown]
# ## Data sources

# %%
data_summary = pd.DataFrame([
    {'dataset': 'sonar.csv', 'task': 'classification', 'source': 'local file'},
    {'dataset': 'auto-insurance.csv', 'task': 'regression', 'source': 'local file'},
    {'dataset': 'mobile_price_data_train.csv', 'task': 'multiclass classification', 'source': 'local file'},
])
save_table(data_summary, '00_data_source_summary.csv')
data_summary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_summary = pd.DataFrame([
#       2     {'dataset': 'sonar.csv', 'task': 'classification', 'source': 'local file'},
#       3     {'dataset': 'auto-insurance.csv', 'task': 'regression', 'source': 'local file'},
#       4     {'dataset': 'mobile_price_data_train.csv', 'task': 'multiclass classification', 'source': 'local file'},
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Sonar: Logistic Regression

# %%
sonar_results = sonar_experiments()
save_table(sonar_results, '01_sonar_grid_random_results.csv')
save_bar(sonar_results, 'experiment', 'best_score', 'Sonar: Grid Search vs Random Search', '01_sonar_grid_random_results.png')
sonar_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sonar_results = sonar_experiments()
#       2 save_table(sonar_results, '01_sonar_grid_random_results.csv')
#       3 save_bar(sonar_results, 'experiment', 'best_score', 'Sonar: Grid Search vs Random Search', '01_sonar_grid_random_results.png')
#       4 sonar_results
#
# NameError: name 'sonar_experiments' is not defined

# %% [markdown]
# ## Auto Insurance: Ridge Regression

# %%
auto_results = auto_insurance_experiments()
save_table(auto_results, '02_auto_insurance_grid_random_results.csv')
plot_auto = auto_results.copy()
plot_auto['mae'] = -plot_auto['best_score']
save_bar(plot_auto, 'experiment', 'mae', 'Auto Insurance: MAE Comparison', '02_auto_insurance_grid_random_results.png')
auto_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 auto_results = auto_insurance_experiments()
#       2 save_table(auto_results, '02_auto_insurance_grid_random_results.csv')
#       3 plot_auto = auto_results.copy()
#       4 plot_auto['mae'] = -plot_auto['best_score']
#
# NameError: name 'auto_insurance_experiments' is not defined

# %% [markdown]
# ## Nested Cross-Validation

# %%
nested_results = nested_cv_experiment()
save_table(nested_results, '03_nested_cv_results.csv')
nested_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 nested_results = nested_cv_experiment()
#       2 save_table(nested_results, '03_nested_cv_results.csv')
#       3 nested_results
#
# NameError: name 'nested_cv_experiment' is not defined

# %% [markdown]
# ## Mobile Price: Hyperopt / TPE

# %%
hyperopt_results, trials_df = hyperopt_mobile_experiment()
save_table(hyperopt_results, '04_mobile_hyperopt_results.csv')
if len(trials_df):
    save_table(trials_df, '05_hyperopt_trials.csv')
    plt.figure(figsize=(8, 5))
    plt.plot(trials_df['trial'], trials_df['accuracy'])
    plt.xlabel('Trial')
    plt.ylabel('CV accuracy')
    plt.title('Hyperopt/TPE progress on Mobile Price data')
    plt.tight_layout()
    plt.savefig(FIG_DIR / '03_hyperopt_trials_progress.png', dpi=150)
    plt.show()
hyperopt_results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 hyperopt_results, trials_df = hyperopt_mobile_experiment()
#       2 save_table(hyperopt_results, '04_mobile_hyperopt_results.csv')
#       3 if len(trials_df):
#       4     save_table(trials_df, '05_hyperopt_trials.csv')
#
# NameError: name 'hyperopt_mobile_experiment' is not defined

# %% [markdown]
# ## Final summary

# %%
final = pd.concat([
    sonar_results,
    auto_results,
    nested_results.rename(columns={'mean_accuracy': 'best_score'}),
    hyperopt_results,
], ignore_index=True, sort=False)
save_table(final, '06_final_summary.csv')
final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 final = pd.concat([
#       2     sonar_results,
#       3     auto_results,
#       4     nested_results.rename(columns={'mean_accuracy': 'best_score'}),
#
# NameError: name 'pd' is not defined
