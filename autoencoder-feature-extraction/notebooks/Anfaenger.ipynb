# %% [markdown]
# ## Exercise 1: Simple Autoencoder in Keras
# **Dataset Used:** MNIST (keras.datasets)
#
# 1. Load MNIST, normalize to [0,1]. Build: Input(784)->Dense(128)->Dense(32)->Dense(128)->Dense(784).
# 2. Train with binary_crossentropy + adam for 10 epochs. Plot loss.
# 3. Visualize 10 original and reconstructed images.

# %% [markdown]
# ## Dataset Validation
# Run this cell to verify that your datasets are present and correctly formatted.

# %%
# --- DATASET VALIDATION ---
import os
import pandas as pd

def validate_dataset(filepath, expected_columns=None, avoid_columns=None):
    if not os.path.exists(filepath):
        print(f'❌ ERROR: Dataset not found at {filepath}')
        return False
    try:
        df = pd.read_csv(filepath, nrows=5)
        print(f'✅ SUCCESS: Dataset found at {filepath} (Columns: {df.shape[1]})')
        if expected_columns:
            missing = [c for c in expected_columns if c not in df.columns]
            if missing:
                print(f'⚠️ WARNING: Missing expected columns: {missing}')
                return False
        if avoid_columns:
            forbidden = [c for c in avoid_columns if c in df.columns]
            if forbidden:
                print(f'❌ ERROR: Found forbidden columns {forbidden}. Wrong dataset!')
                return False
        return True
    except Exception as e:
        print(f'❌ ERROR: Could not read dataset: {e}')
        return False

print('Validation helper loaded. Call validate_dataset(path) before loading your data.')
# validate_dataset('../data/your_dataset.csv')
# Out:
# Validation helper loaded. Call validate_dataset(path) before loading your data.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input

# 1. Load and Normalize
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Build Autoencoder
input_img = Input(shape=(784,))
encoded = Dense(128, activation='relu')(input_img)
encoded = Dense(32, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(encoded)
decoded = Dense(784, activation='sigmoid')(decoded)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 2. Train
history = autoencoder.fit(x_train, x_train,
                epochs=10,
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test),
                verbose=1)

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Autoencoder Loss')
plt.legend()
plt.show()

# 3. Visualize
decoded_imgs = autoencoder.predict(x_test)
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
    # Reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28), cmap='gray')
    ax.axis('off')
plt.show()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 3:08 806ms/step - loss: 0.6948
#  13/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6649
#  26/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5999
#  40/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5441
#  53/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5068
#  67/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4767
#  81/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4530
#  96/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4325
# 110/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4164
# 124/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4026
# 140/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3888
# 156/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3767
# 169/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3679
# 183/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3594
# 197/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3515
# 212/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3439
# 226/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3373
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2325 - val_loss: 0.1537
# Epoch 2/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - loss: 0.1523
#  13/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1555
#  26/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1547
#  41/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1538
#  55/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1530
#  68/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1522
#  82/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1515
#  96/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1508
# 110/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1501
# 125/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1493
# 138/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1487
# 153/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1481
# 167/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1474
# 181/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1469
# 196/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1462
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1456
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1451
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1360 - val_loss: 0.1203
# Epoch 3/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.1211
#  15/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1207
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1209
#  42/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1209
#  55/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1208
#  69/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1206
#  84/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1204
#  98/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1202
# 111/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1201
# 126/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1199
# 141/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1197
# 156/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1195
# 170/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1193
# 183/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1192
# 198/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1190
# 214/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1188
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1187
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1158 - val_loss: 0.1095
# Epoch 4/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - loss: 0.1147
#  15/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1119
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1116
#  43/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1114
#  59/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1112
#  73/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1110
#  88/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1108
# 103/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1106
# 118/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1105
# 132/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1104
# 145/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1103
# 159/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1101
# 173/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1100
# 187/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1099
# 201/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1098
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1097
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1096
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1080 - val_loss: 0.1037
# Epoch 5/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.1062
#  14/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045
#  28/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045
#  42/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1046
#  55/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1046
#  69/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1046
#  83/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1046
#  97/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1046
# 112/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045
# 126/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045
# 141/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1045
# 155/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1044
# 171/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1043
# 186/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1043
# 200/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1042
# 214/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1042
# 228/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1041
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1032 - val_loss: 0.1000
# Epoch 6/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - loss: 0.1036
#  15/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1014
#  28/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1011
#  42/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1010
#  57/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1010
#  71/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1009
#  85/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1009
# 100/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1008
# 114/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1008
# 128/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1008
# 141/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1008
# 155/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1007
# 169/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1007
# 183/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1007
# 197/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1006
# 211/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1006
# 225/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1006
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.1001 - val_loss: 0.0973
# Epoch 7/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 6s 29ms/step - loss: 0.1005
#  17/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0996
#  31/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0991
#  45/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0989
#  59/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0988
#  73/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0987
#  87/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0986
# 101/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0985
# 117/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0984
# 132/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0984
# 145/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0984
# 160/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0983
# 174/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0983
# 188/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0982
# 201/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0982
# 216/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0982
# 229/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0981
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0976 - val_loss: 0.0953
# Epoch 8/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 1:12 310ms/step - loss: 0.0953
#  14/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
#  28/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
#  41/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
#  56/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
#  70/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
#  86/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
#  99/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
# 114/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
# 128/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
# 142/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0965
# 157/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
# 172/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
# 187/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
# 201/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0964
# 215/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0963
# 231/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0963
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0959 - val_loss: 0.0939
# Epoch 9/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0931
#  15/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0951
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0953
#  43/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
#  57/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
#  71/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
#  85/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
#  99/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
# 112/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
# 128/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0952
# 142/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0951
# 157/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0951
# 171/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0951
# 186/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0951
# 200/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0951
# 214/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0950
# 227/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0950
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0947 - val_loss: 0.0928
# Epoch 10/10
#   1/235 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - loss: 0.0920
#  15/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0931
#  29/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0935
#  44/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
#  58/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
#  72/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
#  86/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
# 100/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
# 112/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
# 126/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
# 139/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0936
# 153/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0937
# 167/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0937
# 181/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0937
# 194/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0937
# 208/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0937
# 221/235 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0937
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0936 - val_loss: 0.0920
#   1/313 ━━━━━━━━━━━━━━━━━━━━ 12s 40ms/step
#  50/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 101/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 152/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 204/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 257/313 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
